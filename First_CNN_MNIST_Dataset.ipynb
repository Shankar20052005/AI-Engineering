# %% [markdown]
# <a href="https://colab.research.google.com/github/Shankar20052005/AI-Engineering/blob/main/First_CNN_MNIST_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt

# %%
transform = transforms.Compose([transforms.ToTensor()])

# Download MNIST dataset
trainset = torchvision.datasets.MNIST(root='./data', train=True, download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=1, shuffle=True)

print("MNIST dataset loaded ✅")
# Out:
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 53.7MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 1.75MB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 14.6MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 5.88MB/s]
# MNIST dataset loaded ✅

# %%
class SimpleCNN(nn.Module):
    def __init__(self):
        super(SimpleCNN, self).__init__()
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=4, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(4, 8, kernel_size=3, padding=1)

    def forward(self, x):
        x = self.conv1(x)
        x = torch.relu(x)
        self.feat1 = x  # Save first layer's output for visualization
        x = self.conv2(x)
        x = torch.relu(x)
        self.feat2 = x  # Save second layer's output
        return x

# %%
class SimpleCNN(nn.Module):
    def __init__(self):
        super(SimpleCNN, self).__init__()
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=4, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(4, 8, kernel_size=3, padding=1)

    def forward(self, x):
        x = self.conv1(x)
        x = torch.relu(x)
        self.feat1 = x  # Save first layer's output for visualization
        x = self.conv2(x)
        x = torch.relu(x)
        self.feat2 = x  # Save second layer's output
        return x

# %%
cnn = SimpleCNN()  # create model
dataiter = iter(trainloader)  # get 1 image
images, labels = next(dataiter)

# Run the image through the CNN
_ = cnn(images)

print("Image shape:", images.shape)
print("Feature map 1 shape:", cnn.feat1.shape)
print("Feature map 2 shape:", cnn.feat2.shape)
# Out:
# Image shape: torch.Size([1, 1, 28, 28])
# Feature map 1 shape: torch.Size([1, 4, 28, 28])
# Feature map 2 shape: torch.Size([1, 8, 28, 28])

# %%
# Show input image
plt.imshow(images[0][0].detach(), cmap='gray')
plt.title("Input Image (Digit: {})".format(labels.item()))
plt.axis('off')
plt.show()

# Show all 4 feature maps from conv1
for i in range(4):
    plt.imshow(cnn.feat1[0][i].detach(), cmap='gray')
    plt.title(f"Feature Map {i+1} from Conv1")
    plt.axis('off')
    plt.show()

# %%
# Show input image
plt.imshow(images[0][0].detach(), cmap='gray')
plt.title("Input Image (Digit: {})".format(labels.item()))
plt.axis('off')
plt.show()

# Show all 4 feature maps from conv1
for i in range(4):
    plt.imshow(cnn.feat2[0][i].detach(), cmap='gray')
    plt.title(f"Feature Map {i+1} from Conv2")
    plt.axis('off')
    plt.show()

# %%
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt

# %%
transform = transforms.Compose([transforms.ToTensor()])

# Download MNIST dataset
trainset = torchvision.datasets.MNIST(root='./data', train=True, download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=1, shuffle=True)

print("MNIST dataset loaded")
# Out:
# MNIST dataset loaded

# %%
class SimpleCNN(nn.Module):
    def __init__(self):
        super(SimpleCNN, self).__init__()
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=4, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(4, 8, kernel_size=3, padding=1)

    def forward(self, x):
        x = self.conv1(x)
        x = torch.relu(x)
        self.feat1 = x  # Save first layer's output for visualization
        x = self.conv2(x)
        x = torch.relu(x)
        self.feat2 = x  # Save second layer's output
        return x

# %%
cnn = SimpleCNN()  # create model
dataiter = iter(trainloader)  # get 1 image
images, labels = next(dataiter)

# Run the image through the CNN
_ = cnn(images)

print("Image shape:", images.shape)
print("Feature map 1 shape:", cnn.feat1.shape)
print("Feature map 2 shape:", cnn.feat2.shape)
# Out:
# Image shape: torch.Size([1, 1, 28, 28])
# Feature map 1 shape: torch.Size([1, 4, 28, 28])
# Feature map 2 shape: torch.Size([1, 8, 28, 28])

# %%
# Show input image
plt.imshow(images[0][0].detach(), cmap='gray')
plt.title("Input Image (Digit: {})".format(labels.item()))
plt.axis('off')
plt.show()

# Show all 4 feature maps from conv1
for i in range(4):
    plt.imshow(cnn.feat1[0][i].detach(), cmap='gray')
    plt.title(f"Feature Map {i+1} from Conv1")
    plt.axis('off')
    plt.show()

# %%
# Show input image
plt.imshow(images[0][0].detach(), cmap='gray')
plt.title("Input Image (Digit: {})".format(labels.item()))
plt.axis('off')
plt.show()

# Show all 8 feature maps from conv2
for i in range(8):
    plt.imshow(cnn.feat2[0][i].detach(), cmap='gray')
    plt.title(f"Feature Map {i+1} from Conv2")
    plt.axis('off')
    plt.show()
